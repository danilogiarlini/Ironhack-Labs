# %% [markdown]
# The scope of this notebbok is to describe Aycha's next vacations

# %%
name = str(input("My name is ")) #Through this function is it possible to input the name of the person
# Out:
# My name is Aycha

# %% [markdown]
# ![clean-girl-makeup.jpg](attachment:clean-girl-makeup.jpg)

# %% [markdown]
# Her desired holiday destination is Bali

# %% [markdown]
# ![intercontinental-bali-6362988682-2x1.jpeg](attachment:intercontinental-bali-6362988682-2x1.jpeg)

# %% [markdown]
# The activities she's going to do are:
# - Swim
# - Swim
# - And swim!!!
